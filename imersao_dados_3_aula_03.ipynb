# %%
# Importa biblioteca e le o arquivo
import pandas as pd 

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

df = pd.read_csv(url_dados, compression = 'zip')

# %%
# Altera o nome da coluna
mapa = {'droga': 'composto'}
df.rename(columns = mapa, inplace = True)

df.head()
# Out:
#              id tratamento  tempo dose   composto     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %% [markdown]
# ## Correlacionando os dados

# %%
# Cria tabela de correlação
pd.crosstab([df['dose'], df['tempo']], df['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([df['dose'], df['tempo']], df['tratamento'], normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([df['dose'], df['tempo']], df['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([df['dose'], df['tempo']], df['tratamento'], values = df['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

sns.scatterplot(x='g-0', y='g-3', data = df)
plt.show()

# %%
sns.scatterplot(x='g-0', y='g-8', data = df)
plt.show()

# %%
sns.lmplot(data = df, x='g-0', y='g-8', line_kws={'color': 'red'})
plt.show()

# %%
sns.lmplot(data = df, x='g-0', y='g-8', line_kws={'color': 'red'}, col='tratamento', row='tempo')
plt.show()

# %%
df.loc[:, 'g-0': 'g-771'].corr()
# Out:
#             g-0       g-1       g-2       g-3       g-4       g-5       g-6  \
# g-0    1.000000  0.086032  0.176188  0.011266  0.403153 -0.165478  0.238348
# g-1    0.086032  1.000000 -0.054518 -0.027855  0.193647 -0.151590 -0.122541
# g-2    0.176188 -0.054518  1.000000  0.042633  0.013968  0.018516  0.015190
# g-3    0.011266 -0.027855  0.042633  1.000000 -0.033039  0.042231 -0.043177
# g-4    0.403153  0.193647  0.013968 -0.033039  1.000000 -0.057449  0.206405
# ...         ...       ...       ...       ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149 -0.179370  0.124425 -0.081016 -0.000886
# g-768  0.300241 -0.030756  0.115415  0.028452  0.115579 -0.139000 -0.005791
# g-769 -0.127375 -0.006866  0.014489 -0.206077 -0.172727 -0.068537 -0.278587
# g-770 -0.514201 -0.095108 -0.078661 -0.002142 -0.363673  0.144631 -0.143428
# g-771  0.405908 -0.032233  0.103985  0.058219  0.250713 -0.093237  0.075019
#
# ...

# %%
import numpy as np

# Compute the correlation matrix
corr = df.loc[:, 'g-0': 'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Compute the correlation matrix
corr_cell = df.loc[:, 'c-0': 'c-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_cell, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_cell, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Desafios da aula:
#   #### - Deafio 01: Criar tabela de frequência com pandas.groupby()
#   #### - Deafio 02: Normalizar o crosstab pelas colunas
#   #### - Deafio 03: Explorar outros agregadores
#   #### - Deafio 04: Explorar o melt
#   #### - Deafio 05: Calcular e analisar a correlação entre G e C. Refletir sobre os efeitos bioquimicos
#   #### - Deafio 06: Estudar o código que plota a matriz de correlação (heatmap)
#   #### - Deafio 07: Resumo do que aprendeu com os dados

# %% [markdown]
# ### Desafio 01

# %%
# Utilizando .groupby() 
df.groupby(['dose','tempo','tratamento']).size()
# Out:
# dose  tempo  tratamento
# D1    24     com_controle     301
#              com_droga       3585
#       48     com_controle     343
#              com_droga       4011
#       72     com_controle     307
#              com_droga       3600
# D2    24     com_controle     305
#              com_droga       3581
#       48     com_controle     305
#              com_droga       3591
#       72     com_controle     305
#              com_droga       3580
# dtype: int64

# %% [markdown]
# ### Desafio 02

# %%
# Normalizando crosstab pelas colunas
pd.crosstab([df['dose'], df['tempo']], df['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ### Desafio 03

# %%
# Função soma agregada
pd.crosstab([df['dose'], df['tempo']], df['tratamento'], values = df['g-0'], aggfunc='sum')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         -75.7799  1319.2648
#      48         -42.1113  1654.4150
#      72         -90.6483  1030.5010
# D2   24           3.2800   412.7202
#      48           4.0180   770.1980
#      72          21.4262   907.3112

# %% [markdown]
# ### Desafio 04

# %%
#  A função melt() muda o data frame de wide para long
pd.melt(df.head(), id_vars='id', value_vars='tempo')
# Out:
#              id variable  value
# 0  id_000644bb2    tempo     24
# 1  id_000779bfc    tempo     72
# 2  id_000a6266a    tempo     48
# 3  id_0015fd391    tempo     48
# 4  id_001626bd3    tempo     72

# %% [markdown]
# ### Desafio 05

# %%
#Correlacionando G e C

# Compute the correlation matrix
corr_cell = pd.concat([df.loc[:,'g-0':'g-9'], df.loc[:,'c-0':'c-9']], axis=1)
cor = corr_cell.corr().loc['c-0':'c-9','g-0':'g-9']

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(cor,  cmap=cmap, center=0,   
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ### Desafio 07

# %% [markdown]
# - Alguns genes são altamentes correlacionados enquanto outros não
# - A correlação do  grupo com controle tem comportamento esperado, permanecendo centralizados e estáveis
